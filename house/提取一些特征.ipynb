# %%
import tensorflow as tf
import math

# %%
all_lines=open('/home/zzq/kaggle/house/train.csv').readlines()

# %%
print all_lines[1]
# Out:
# 1,2011-08-20,43,27,4,NA,NA,NA,NA,NA,NA,Investment,Bibirevo,6407578.1,155572,0.189727117,6.99893e-5,9576,5001,5,10309,11065,5,0,240,1,0,7,3,no,0,16,1,no,no,no,no,no,no,no,no,86206,40477,45729,21154,11007,10147,98207,52277,45930,36211,10580,25631,9576,4899,4677,10309,5463,4846,23603,12286,11317,17508,9425,8083,18654,9709,8945,211,25,0,0,0,2,184,0,0,0,211,0,0,0,206,5,1,2.590241095,1.131259906,13.57511887,1.131259906,0.145699552,0.17797535,2.158587074,0.600973099,1.080934313,23.68346,1.804127,3.633334,5.419893032,65.03871639,1,5.419893032,6.905892968,1,0.274985143,3.299821714,0.992631058,no,1.42239141,10.9185867,13.10061764,13.67565705,15.15621058,1.422391404,1,no,3.830951404,5,1.305159492,no,14.23196091,101,24.2924061,1,18.152338,5.718518835,1.210027392,1.062513046,5.814134663,4.308127002,10.81417151,1.676258313,0.485841388,3.065047099,1.107594209,8.148590774,3.516512911,2.392353035,4.248035887,0.974742843,6.715025787,0.884350021,0.648487637,0.637188832,0.947961657,0.17797535,0.62578343
# ...

# %%
demo=all_lines[1]
print len(demo)
# Out:
# 1553

# %%
demo_=demo.split(',')
print demo_
# Out:
# ['1', '2011-08-20', '43', '27', '4', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'Investment', 'Bibirevo', '6407578.1', '155572', '0.189727117', '6.99893e-5', '9576', '5001', '5', '10309', '11065', '5', '0', '240', '1', '0', '7', '3', 'no', '0', '16', '1', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', '86206', '40477', '45729', '21154', '11007', '10147', '98207', '52277', '45930', '36211', '10580', '25631', '9576', '4899', '4677', '10309', '5463', '4846', '23603', '12286', '11317', '17508', '9425', '8083', '18654', '9709', '8945', '211', '25', '0', '0', '0', '2', '184', '0', '0', '0', '211', '0', '0', '0', '206', '5', '1', '2.590241095', '1.131259906', '13.57511887', '1.131259906', '0.145699552', '0.17797535', '2.158587074', '0.600973099', '1.080934313', '23.68346', '1.804127', '3.633334', '5.419893032', '65.03871639', '1', '5.419893032', '6.905892968', '1', '0.274985143', '3.299821714', '0.992631058', 'no', '1.42239141', '10.9185867', '13.10061764', '13.67565705', '15.15621058', '1.422391
# ...

# %%
print len(demo_)
# Out:
# 292

# %%
demo2=all_lines[2].strip('\n')
demo2_=demo2.split(',')

# %%
list_=all_lines[0]
list_demo=list_.strip('\n')
lins=list_demo.split(',')

# %%
#coding=utf-8
import os
if os.path.isfile('/home/zzq/kaggle/house/特征示意'):
    os.remove('/home/zzq/kaggle/house/特征示意')
for i in range(len(lins)):
    out=file('/home/zzq/kaggle/house/特征示意','a+')
    xian='NO. ' + str(i+1)+ '\t' + str(lins[i])+'\t'+str(demo_[i])+'\t'+str(demo2_[i])+'\n'
    out.write(xian)
    out.close()

# %%
def write_feature
